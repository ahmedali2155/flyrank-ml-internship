# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ahmedali2155/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane
#
# I chose **Lane 2: Refresh / Content Opportunity Scoring**.
#
# I selected this lane because it focuses on helping content teams decide which pages should be reviewed first for refresh or improvement. This problem has practical value because websites often have many pages but limited time and resources to review them all. I want to explore how observable search and engagement signals can be combined to create a ranked list of pages that deserve attention. This lane also builds directly on the starter notebooks and provides a strong foundation for my capstone project.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ## Research Question
#
# Which website pages should be reviewed first for content refresh based on observable search and engagement signals?
#
# **Decision**
#
# Prioritize which pages should be reviewed first.
#
# **Action**
#
# A content reviewer or SEO specialist reviews the highest-ranked pages and decides whether to refresh, expand, monitor, or improve them.
#
# **Cost of a Wrong Recommendation**
#
# If low-priority pages are recommended, valuable time and resources may be wasted. If important pages are missed, opportunities to improve website performance may be delayed. The recommendations should therefore support human decision-making rather than replace it.
#
# **Unit of Analysis**
#
# Each row represents one content page. The goal is to evaluate and rank individual pages for potential content refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick Look at the Data
#
# The starter dataset suggests that combining multiple observable signals may be more useful than relying on a single metric.
#
# In the starter notebook, the correlation between **search_volume** and **impressions_90d** was approximately **0.001**, showing almost no linear relationship between these two variables alone.
#
# After increasing the Decision Tree model depth from 2 to 3, the model's performance improved:
#
# - Precision@20 improved from **0.550** to **0.700**
# - Precision@50 improved from **0.600** to **0.720**
#
# These observations suggest that combining several features can produce a better ranking than relying on a simple rule or a single metric.

# %%
import pandas as pd

df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Average impressions_90d:", round(df["impressions_90d"].mean(), 2))
print("Average CTR:", round(df["ctr"].mean(), 3))
# Out:
# Number of pages: 30000
# Average impressions_90d: 5200.37
# Average CTR: 0.511

# %% [markdown]
# ## 4. Careful words:
#
# ## What I Can and Cannot Claim
#
# This project can identify observed patterns and provide decision-support recommendations based on the available data. It can rank pages that may deserve review using measurable search and engagement signals.
#
# However, this project cannot prove that a content refresh will improve performance or reveal how Google's ranking algorithms work. Any findings will be presented as observations from the available dataset, and important content decisions should still include human review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
